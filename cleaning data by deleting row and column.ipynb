# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

# %%
df=pd.read_csv(r"C:\Users\user\Desktop\monster_com-job_sample.csv")

# %%
df
# Out:
#                         country country_code date_added has_expired  \
# 0      United States of America           US        NaN          No
# 1      United States of America           US        NaN          No
# 2      United States of America           US        NaN          No
# 3      United States of America           US        NaN          No
# 4      United States of America           US        NaN          No
# ...                         ...          ...        ...         ...
# 21995  United States of America           US        NaN          No
# 21996  United States of America           US        NaN          No
# 21997  United States of America           US        NaN          No
# 21998  United States of America           US        NaN          No
# 21999  United States of America           US        NaN          No
#
#               job_board                                    job_description  \
# ...

# %%
df.shape
# Out:
# (22000, 14)

# %%
df.head()
# Out:
#                     country country_code date_added has_expired  \
# 0  United States of America           US        NaN          No
# 1  United States of America           US        NaN          No
# 2  United States of America           US        NaN          No
# 3  United States of America           US        NaN          No
# 4  United States of America           US        NaN          No
#
#           job_board                                    job_description  \
# 0  jobs.monster.com  TeamSoft is seeing an IT Support Specialist to...
# 1  jobs.monster.com  The Wisconsin State Journal is seeking a flexi...
# 2  jobs.monster.com  Report this job About the Job DePuy Synthes Co...
# 3  jobs.monster.com  Why Join Altec? If you’re considering a career...
# 4  jobs.monster.com  Position ID#  76162 # Positions  1 State  CT C...
#
#                                            job_title             job_type  \
# 0               IT Support Technician Job in Madison   Full Time Employee
# ...

# %%
df.tail()
# Out:
#                         country country_code date_added has_expired  \
# 21995  United States of America           US        NaN          No
# 21996  United States of America           US        NaN          No
# 21997  United States of America           US        NaN          No
# 21998  United States of America           US        NaN          No
# 21999  United States of America           US        NaN          No
#
#               job_board                                    job_description  \
# 21995  jobs.monster.com  This is a major premier Cincinnati based finan...
# 21996  jobs.monster.com  Luxury homebuilder in Cincinnati seeking multi...
# 21997  jobs.monster.com  RE: Adobe AEM-          Client -          Loca...
# 21998  jobs.monster.com  Jernberg Industries was established in 1937 an...
# 21999  jobs.monster.com  Contract AdministratorCan you be the point per...
#
#                                                job_title            job_type  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22000 entries, 0 to 21999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   country          22000 non-null  object
#  1   country_code     22000 non-null  object
#  2   date_added       122 non-null    object
#  3   has_expired      22000 non-null  object
#  4   job_board        22000 non-null  object
#  5   job_description  22000 non-null  object
#  6   job_title        22000 non-null  object
#  7   job_type         20372 non-null  object
#  8   location         22000 non-null  object
#  9   organization     15133 non-null  object
#  10  page_url         22000 non-null  object
#  11  salary           3446 non-null   object
#  12  sector           16806 non-null  object
#  13  uniq_id          22000 non-null  object
# dtypes: object(14)
# memory usage: 2.3+ MB

# %%
df.isnull()
# Out:
#        country  country_code  date_added  has_expired  job_board  \
# 0        False         False        True        False      False
# 1        False         False        True        False      False
# 2        False         False        True        False      False
# 3        False         False        True        False      False
# 4        False         False        True        False      False
# ...        ...           ...         ...          ...        ...
# 21995    False         False        True        False      False
# 21996    False         False        True        False      False
# 21997    False         False        True        False      False
# 21998    False         False        True        False      False
# 21999    False         False        True        False      False
#
#        job_description  job_title  job_type  location  organization  page_url  \
# 0                False      False     False     False          True     False
# ...

# %%
df.isnull().sum()
# Out:
# country                0
# country_code           0
# date_added         21878
# has_expired            0
# job_board              0
# job_description        0
# job_title              0
# job_type            1628
# location               0
# organization        6867
# page_url               0
# salary             18554
# sector              5194
# uniq_id                0
# dtype: int64

# %%
plt.figure(figsize=(16,9))
sn.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
null_var=df.isnull().sum()/df.shape[0]*100
null_var
# Out:
# country             0.000000
# country_code        0.000000
# date_added         99.445455
# has_expired         0.000000
# job_board           0.000000
# job_description     0.000000
# job_title           0.000000
# job_type            7.400000
# location            0.000000
# organization       31.213636
# page_url            0.000000
# salary             84.336364
# sector             23.609091
# uniq_id             0.000000
# dtype: float64

# %%
drop_coloumns=null_var[null_var>20]
drop_coloumns
# Out:
# date_added      99.445455
# organization    31.213636
# salary          84.336364
# sector          23.609091
# dtype: float64

# %%
drop_coloumns=null_var[null_var>17].keys()

# %%
df_drop_clm=df.drop(columns=drop_coloumns,axis=1)

# %%
df_drop_clm
# Out:
#                         country country_code has_expired         job_board  \
# 0      United States of America           US          No  jobs.monster.com
# 1      United States of America           US          No  jobs.monster.com
# 2      United States of America           US          No  jobs.monster.com
# 3      United States of America           US          No  jobs.monster.com
# 4      United States of America           US          No  jobs.monster.com
# ...                         ...          ...         ...               ...
# 21995  United States of America           US          No  jobs.monster.com
# 21996  United States of America           US          No  jobs.monster.com
# 21997  United States of America           US          No  jobs.monster.com
# 21998  United States of America           US          No  jobs.monster.com
# 21999  United States of America           US          No  jobs.monster.com
#
#                                          job_description  \
# ...

# %%
df_drop_clm.shape
# Out:
# (22000, 10)

# %%
plt.figure(figsize=(16,9))
sn.heatmap(df_drop_clm.isnull())
# Out:
# <AxesSubplot:>

# %%
df3_drop_rows=df_drop_clm.dropna()
df3_drop_rows
# Out:
#                         country country_code has_expired         job_board  \
# 0      United States of America           US          No  jobs.monster.com
# 1      United States of America           US          No  jobs.monster.com
# 2      United States of America           US          No  jobs.monster.com
# 3      United States of America           US          No  jobs.monster.com
# 4      United States of America           US          No  jobs.monster.com
# ...                         ...          ...         ...               ...
# 21995  United States of America           US          No  jobs.monster.com
# 21996  United States of America           US          No  jobs.monster.com
# 21997  United States of America           US          No  jobs.monster.com
# 21998  United States of America           US          No  jobs.monster.com
# 21999  United States of America           US          No  jobs.monster.com
#
#                                          job_description  \
# ...

# %%
df3_drop_rows.shape
# Out:
# (20372, 10)

# %%
plt.figure(figsize=(16,9))
sn.heatmap(df3_drop_rows.isnull())
# Out:
# <AxesSubplot:>

# %%
df3_drop_rows.isnull().sum()
# Out:
# country            0
# country_code       0
# has_expired        0
# job_board          0
# job_description    0
# job_title          0
# job_type           0
# location           0
# page_url           0
# uniq_id            0
# dtype: int64

# %%
df3_drop_rows.isnull().select_dtypes(include=['int64','float64']).columns
# Out:
# Index([], dtype='object')

# %%
df3_drop_rows.select_dtypes(include=['object']).columns
# Out:
# Index(['country', 'country_code', 'has_expired', 'job_board',
#        'job_description', 'job_title', 'job_type', 'location', 'page_url',
#        'uniq_id'],
#       dtype='object')

# %%
df['job_title'].value_counts()
# Out:
# Monster                                                 318
# Shift Supervisor Job in Camphill                        256
# RN                                                       70
# Shift Supervisor - Part-Time Job in Camphill             56
# Manager                                                  50
#                                                        ...
# Sales Job in Knoxville                                    1
# Merchandiser Job in Madison                               1
# Retail Project Merchandiser Part Time Job in Madison      1
# Senior Windows Systems Administrator* Job in Madison      1
# Contract Administrator Job in Cincinnati                  1
# Name: job_title, Length: 18759, dtype: int64

# %%
df['job_title'].value_counts()/df3_drop_rows.shape[0]*100,df3_drop_rows['job_title'].value_counts()/df3_drop_rows.shape[0]*100
# Out:
# (Monster                                                 1.560966
#  Shift Supervisor Job in Camphill                        1.256627
#  RN                                                      0.343609
#  Shift Supervisor - Part-Time Job in Camphill            0.274887
#  Manager                                                 0.245435
#                                                            ...
#  Sales Job in Knoxville                                  0.004909
#  Merchandiser Job in Madison                             0.004909
#  Retail Project Merchandiser Part Time Job in Madison    0.004909
#  Senior Windows Systems Administrator* Job in Madison    0.004909
#  Contract Administrator Job in Cincinnati                0.004909
#  Name: job_title, Length: 18759, dtype: float64,
#  Shift Supervisor Job in Camphill                          1.256627
#  Monster                                                   0.824661
# ...
